# %% [markdown]
# <a href="https://colab.research.google.com/github/Vyshnavi-punati/IRS-LAB/blob/main/IRS_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #checking similarity between data.

# %% [markdown]
# With Similar data

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
doc1="Machine learning is a branch of artificial intelligence that focuses on building applications that learn from data."
doc2="Artificial intelligence and machine learning ar widely used to make smart applications based on data."
documents=[doc1,doc2]
vectorizer=TfidfVectorizer(stop_words='english')
tfidf_matrix=vectorizer.fit_transform(documents)
similarity_score=cosine_similarity(tfidf_matrix[0:1],tfidf_matrix[1:2])[0][0]
print("Cosine Similarity between Document 1 and Document 2.")
print(f"{similarity_score:.4f}")
# Out:
# Cosine Similarity between Document 1 and Document 2.
# 0.3809

# %% [markdown]
# Without similar data

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
doc1="History is the systematic study and interpretation of human past."
doc2="Artificial intelligence and machine learning ar widely used to make smart applications based on data."
documents=[doc1,doc2]
vectorizer=TfidfVectorizer(stop_words='english')
tfidf_matrix=vectorizer.fit_transform(documents)
similarity_score=cosine_similarity(tfidf_matrix[0:1],tfidf_matrix[1:2])[0][0]
print("Cosine Similarity between Document 1 and Document 2.")
print(f"{similarity_score:.4f}")
# Out:
# Cosine Similarity between Document 1 and Document 2.
# 0.0000

# %% [markdown]
# with same data

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
doc1="Machine learning is a branch of artificial intelligence that focuses on building applications that learn from data."
doc2="Machine learning is a branch of artificial intelligence that focuses on building applications that learn from data."
documents=[doc1,doc2]
vectorizer=TfidfVectorizer(stop_words='english')
tfidf_matrix=vectorizer.fit_transform(documents)
similarity_score=cosine_similarity(tfidf_matrix[0:1],tfidf_matrix[1:2])[0][0]
print("Cosine Similarity between Document 1 and Document 2.")
print(f"{similarity_score:.4f}")
# Out:
# Cosine Similarity between Document 1 and Document 2.
# 1.0000
